# %%
import streamlit as st

# %%
lang = st.text_input("Language")
singer = st.text_input("singer")

btn = st.button("Recommend me songs")

# %%
# !streamlit run music.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://192.168.1.7:8502
#
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1708786044.647321       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# I0000 00:00:1708786059.848189       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786062.303672       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786062.656134       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786066.511207       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786066.748387       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786067.061862       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [libx264 @ 0x28ff918f0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x28ff918f0] profile Constrained Baseline, level 3.1, 4:2:0, 8-bit
# 1/1 [==============================] - 0s 50ms/step
# happy
# [swscaler @ 0x13eab8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# hello
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# hello
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# hello
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x156378000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# hello
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# hello
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# hello
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# hello
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# hello
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# hello
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# hello
# [swscaler @ 0x13eab8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13eab8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13eab8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13eab8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 9ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x156378000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13eae0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13eab8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13eab8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x156378000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x13ead8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13eab8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13eba0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13eab8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x13eab8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x153308000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 10ms/step
# happy
# [swscaler @ 0x153308000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13ead0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x2e5088000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x13eba0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e44a8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [libx264 @ 0x28ff918f0] frame I:2     Avg QP:23.95  size: 17756
# [libx264 @ 0x28ff918f0] frame P:144   Avg QP:31.74  size:  3576
# [libx264 @ 0x28ff918f0] mb I  I16..4: 65.3%  0.0% 34.7%
# [libx264 @ 0x28ff918f0] mb P  I16..4:  1.9%  0.0%  0.2%  P16..4: 17.5%  3.6%  3.6%  0.0%  0.0%    skip:73.3%
# [libx264 @ 0x28ff918f0] final ratefactor: 31.53
# [libx264 @ 0x28ff918f0] coded y,uvDC,uvAC intra: 18.3% 30.5% 9.1% inter: 6.9% 10.2% 6.4%
# [libx264 @ 0x28ff918f0] i16 v,h,dc,p: 41% 23% 26% 11%
# [libx264 @ 0x28ff918f0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 20% 28%  6%  5%  6%  5%  5%  4%
# [libx264 @ 0x28ff918f0] i8c dc,h,v,p: 78%  9% 12%  2%
# [libx264 @ 0x28ff918f0] ref P L0: 81.1%  9.6%  9.3%
# [libx264 @ 0x28ff918f0] kb/s:904.87
# [libx264 @ 0x28ff918f0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x28ff918f0] profile Constrained Baseline, level 3.1, 4:2:0, 8-bit
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x153308000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x153308000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x13cc90000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x153308000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x153308000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x2f9838000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 16ms/step
# happy
# [swscaler @ 0x2e3368000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 25ms/step
# I0000 00:00:1708786073.193502       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# happy
# I0000 00:00:1708786073.230763       2 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786102.262240       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786109.798230       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786136.603800       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786136.869430       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786140.578021       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786140.820308       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# I0000 00:00:1708786141.073601       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [libx264 @ 0x286b0c200] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x286b0c200] profile Constrained Baseline, level 3.1, 4:2:0, 8-bit
# 1/1 [==============================] - 0s 25ms/step
# surprise
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# neutral
# [swscaler @ 0x333880000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x352788000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# sad
# [swscaler @ 0x352c48000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x352c48000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x352550000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# happy
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x352550000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# happy
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# hello
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# hello
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# hello
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x352550000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x352550000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x352550000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x352550000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x352550000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# angry
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# angry
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x337a30000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x352550000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x352550000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# angry
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 6ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 6ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368318000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x352550000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [libx264 @ 0x286b0c200] frame I:2     Avg QP:24.74  size: 18729
# [libx264 @ 0x286b0c200] frame P:140   Avg QP:30.55  size:  3693
# [libx264 @ 0x286b0c200] mb I  I16..4: 61.7%  0.0% 38.3%
# [libx264 @ 0x286b0c200] mb P  I16..4:  1.5%  0.0%  0.1%  P16..4: 18.4%  3.1%  3.5%  0.0%  0.0%    skip:73.4%
# [libx264 @ 0x286b0c200] final ratefactor: 30.55
# [libx264 @ 0x286b0c200] coded y,uvDC,uvAC intra: 18.3% 33.7% 7.9% inter: 6.5% 10.2% 6.1%
# [libx264 @ 0x286b0c200] i16 v,h,dc,p: 41% 23% 24% 12%
# [libx264 @ 0x286b0c200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 22% 25%  5%  4%  5%  4%  5%  4%
# [libx264 @ 0x286b0c200] i8c dc,h,v,p: 72% 11% 15%  2%
# [libx264 @ 0x286b0c200] ref P L0: 80.2%  9.5% 10.3%
# [libx264 @ 0x286b0c200] kb/s:937.20
# [libx264 @ 0x2f78ea010] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x2f78ea010] profile Constrained Baseline, level 3.1, 4:2:0, 8-bit
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x3527e8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# sad
# [swscaler @ 0x368290000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368290000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x3527e8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x3527e8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x35afb0000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368290000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368290000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368290000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368290000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378510000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 8ms/step
# sad
# [swscaler @ 0x3527e8000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368290000] No accelerated colorspace conversion found from yuv420p to bgr24.
# [libx264 @ 0x2f78ea010] frame I:1     Avg QP:27.94  size: 19352
# [libx264 @ 0x2f78ea010] frame P:39    Avg QP:30.58  size:  2980
# [libx264 @ 0x2f78ea010] mb I  I16..4: 67.9%  0.0% 32.1%
# [libx264 @ 0x2f78ea010] mb P  I16..4:  0.3%  0.0%  0.0%  P16..4: 12.3%  2.2%  2.7%  0.0%  0.0%    skip:82.4%
# [libx264 @ 0x2f78ea010] final ratefactor: 30.86
# [libx264 @ 0x2f78ea010] coded y,uvDC,uvAC intra: 28.8% 53.5% 15.7% inter: 5.2% 7.8% 4.7%
# [libx264 @ 0x2f78ea010] i16 v,h,dc,p: 34% 25% 28% 13%
# [libx264 @ 0x2f78ea010] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 21% 26%  6%  5%  6%  4%  6%  5%
# [libx264 @ 0x2f78ea010] i8c dc,h,v,p: 70% 14% 14%  3%
# [libx264 @ 0x2f78ea010] ref P L0: 81.5%  8.8%  9.7%
# [libx264 @ 0x2f78ea010] kb/s:813.32
# [libx264 @ 0x2f78e98d0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x2f78e98d0] profile Constrained Baseline, level 3.1, 4:2:0, 8-bit
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x378608000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 7ms/step
# sad
# [swscaler @ 0x368290000] No accelerated colorspace conversion found from yuv420p to bgr24.
# 1/1 [==============================] - 0s 10ms/step
# sad
# [swscaler @ 0x368290000] No accelerated colorspace conversion found from yuv420p to bgr24.
# I0000 00:00:1708786147.853489       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1
# 1/1 [==============================] - 0s 9ms/step
# sad
